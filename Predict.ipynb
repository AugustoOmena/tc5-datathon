# %% [markdown]
# # Predict

# %% [markdown]
# ### Bibliotecas

# %%
from feast import FeatureStore

# %% [markdown]
# ### Carregamento de Dados (Online) para aplicação ao Modelo (Predição)

# %%
# Primeiro, apontar para o repositório da FeatureStore
on_line_data = FeatureStore(repo_path="feature_repo")

features = on_line_data.get_online_features(
    features=on_line_data.get_feature_service("aluno_service"),
    entity_rows=[{"RA": 'RA-1'}]
).to_df()

print(features)
